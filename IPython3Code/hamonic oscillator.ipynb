# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# this is a note

# %%
m = 1
k = 100
gamma = 0.1
def out(f0,k, gamma):
    w = 2*np.pi*f
    w0 = 2*np.pi*f0
    out = 1/m/(w0**2-w**2-2*1j*gamma*w)
    return out
f0 = np.sqrt(k/m)/2/np.pi

# %%
f = np.logspace(-0.5,1,200)
plt.loglog(f, np.abs(out(f0,k,gamma)))
