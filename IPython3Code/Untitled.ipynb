# %%
print('hello')
# Out:
# hello

# %%
a = 1j*4
b = 2
a+b
# Out:
# (2+4j)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.linspace(0,7,100)
plt.plot(x,np.sin(x))
